# %% [markdown]
# # Megatutorial 1: Explorative Datenanalyse
#
# In diesem Megatutorial beschäftigen wir uns mit der explorativen Datenanalyse in Python.
#
#
# ## Szenario
#
# Wir wurden von einer Social-Media-Plattform damit beauftragt, einen Datensatz mit Profildaten auszuwerten. Das Unternehmen hat uns dazu einen Datensatz mit 576 Profilen zusammengestellt. Aus Datenschutzgründen wurden in diesen Profilen alle personenbezogenen Daten entfernt. Dennoch enthalten die Daten eine Menge an Daten, die Rückschluss auf die Art der Profile enthalten. Darunter sind folgende Merkmale:
#
# * **`profile_pic`:** Eine Bool'sche Variable, die aussagt, ob bei dem Profil ein Profilbild enthalten war, oder nicht.
# * **`rel_num_numeric_char_username`:** Die Anzahl der nummerischen Zeichen im Usernamen, in relation zur Gesamtlänge des Usernamen.
# * **`words_fullname`:** Die Anzahl der Worte im Namensfeld.
# * **`rel_num_numeric_char_fullnam`:** Die Anzahl der nummerischen Zeichen im Namen, in relation zur Gesamtlänge des Namen.
# * **`name=username`:** Eine Bool'sche Variable, die aussagt, ob Username und Name übereinstimmen.
# * **`description_length`:** Die Länge der Bio, die beim betreffenden Profil hinterlegt wurde.
# * **`has_external_url`:** Eine Bool'sche Variable, die aussagt, ob beim Profil eine externe URL (z.B., zu einer Webseite) hinterlegt wurde.
# * **`is_private`:** Eine Bool'sche Variable, die aussagt, ob das betreffende Profil als privat markiert wurde.
# * **`num_posts`:** Die Anzahl der Posts, die von diesem Profil aus gesendet wurden.
# * **`num_followers`:** Die Anzahl der Follower dieses Profils.
# * **`num_follows`:** Die Anzahl der Personen, der dieses Profil folgt.
# * **`is_fake`:** Eine nachträglich eingefügte Target-Variable, die Angibt, ob diese Profil ein Fake-Profil ist, oder nicht.
#
# * b = neue Zeile
#
# ## Aufgaben
#
# * Lade die Daten in `pandas`.
# * Führe eine deskriptive Datenanalyse mit geeigneten, statisches Maßen durch.
# * Führe eine deskriptive Datenanalyse mit Hilfe von geeigneten Visualisierungen durch.

# %%
# !echo hallo welt

# mit echo kann man im terminal etwas printen
# Out:
# hallo welt

# %%
# !pip install pandas

# so wird direkt hier etwas installiert
# Out:
# Requirement already satisfied: pandas in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install -r ../requirements.txt

# mit dem  .. geht er aus dem Code Ordner hinaus
# diesen Codeblock könnte ich löschen, weil es jetzt erledigt ist (ich lasse ihn hier nur zum Verständnis)
# Out:
# Requirement already satisfied: pandas==2.2.3 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: scikit-learn==1.6.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: scipy==1.15.3 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (1.15.3)
# Requirement already satisfied: seaborn==0.13.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (0.13.1)
# Requirement already satisfied: matplotlib==3.9.2 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1->-r ../requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from scikit-learn==1.6.1->-r ../requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pillow>=8 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from matplotlib==3.9.2->-r ../requirements.txt (line 5)) (3.2.3)
# Requirement already satisfied: six>=1.5 in /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirements.txt (line 1)) (1.17.0)

# %% [markdown]
# ## Daten in Pandas laden

# %%
from pandas import read_csv

# %%
data = read_csv (
    "../data/fake_profiles.csv",
    sep=",",
    decimal=".",
    skiprows=None, # Beispiel: skiprows=[0, 1, 10] diese Zeilen sollen geskippt werden
    usecols=range(1, 13) # diese Spalten wollen wir verwenden
    )

data.head(5)
# das heißt nur die ersten 5 Zeilen werden gezeigt
# Out:
#   profile_pic  rel_num_numeric_char_username  words_fullname  \
# 0         yes                           0.27               0
# 1         yes                           0.00               2
# 2         yes                           0.10               2
# 3         yes                           0.00               1
# 4         yes                           0.00               2
#
#    rel_num_numeric_char_fullname name=username  description_length  \
# 0                            0.0            no                  53
# 1                            0.0            no                  44
# 2                            0.0            no                   0
# 3                            0.0            no                  82
# 4                            0.0            no                   0
#
#   has_external_url is_private  num_posts  num_followers  num_follows is_fake
# 0               no         no         32         1000.0          955      no
# 1               no         no        286         2740.0          533      no
# 2               no        yes         13          159.0           98      no
# 3               no         no        679          414.0          651      no
# 4               no        yes          6          151.0          126      no

# %% [markdown]
# ## Deskriptive Statistiken in Pandas

# %%
data.values

# Datenparameter
# Out:
# array([['yes', 0.27, 0, ..., 1000.0, 955, 'no'],
#        ['yes', 0.0, 2, ..., 2740.0, 533, 'no'],
#        ['yes', 0.1, 2, ..., 159.0, 98, 'no'],
#        ...,
#        ['yes', 0.57, 2, ..., 96.0, 339, 'yes'],
#        ['yes', 0.57, 1, ..., 57.0, 73, 'yes'],
#        ['yes', 0.27, 1, ..., 150.0, 487, 'yes']],
#       shape=(576, 12), dtype=object)

# %%
data.head()

# Methode
# Out:
#   profile_pic  rel_num_numeric_char_username  words_fullname  \
# 0         yes                           0.27               0
# 1         yes                           0.00               2
# 2         yes                           0.10               2
# 3         yes                           0.00               1
# 4         yes                           0.00               2
#
#    rel_num_numeric_char_fullname name=username  description_length  \
# 0                            0.0            no                  53
# 1                            0.0            no                  44
# 2                            0.0            no                   0
# 3                            0.0            no                  82
# 4                            0.0            no                   0
#
#   has_external_url is_private  num_posts  num_followers  num_follows is_fake
# 0               no         no         32         1000.0          955      no
# 1               no         no        286         2740.0          533      no
# 2               no        yes         13          159.0           98      no
# 3               no         no        679          414.0          651      no
# 4               no        yes          6          151.0          126      no

# %%
data.info()

# gibt informationen über die Daten
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   profile_pic                    576 non-null    object
#  1   rel_num_numeric_char_username  576 non-null    float64
#  2   words_fullname                 576 non-null    int64
#  3   rel_num_numeric_char_fullname  576 non-null    float64
#  4   name=username                  576 non-null    object
#  5   description_length             576 non-null    int64
#  6   has_external_url               576 non-null    object
#  7   is_private                     576 non-null    object
#  8   num_posts                      576 non-null    int64
#  9   num_followers                  556 non-null    float64
#  10  num_follows                    576 non-null    int64
#  11  is_fake                        576 non-null    object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 54.1+ KB

# %%
data.describe()

# gibt mir Statistische Maßzahlen
# Out:
#        rel_num_numeric_char_username  words_fullname  \
# count                     576.000000      576.000000
# mean                        0.163837        1.460069
# std                         0.214096        1.052601
# min                         0.000000        0.000000
# 25%                         0.000000        1.000000
# 50%                         0.000000        1.000000
# 75%                         0.310000        2.000000
# max                         0.920000       12.000000
#
#        rel_num_numeric_char_fullname  description_length    num_posts  \
# count                     576.000000          576.000000   576.000000
# mean                        0.036094           22.623264   107.489583
# std                         0.125121           37.702987   402.034431
# min                         0.000000            0.000000     0.000000
# 25%                         0.000000            0.000000     0.000000
# 50%                         0.000000            0.000000     9.000000
# 75%                         0.000000           34.000000    81.500000
# max                         1.000000          150.000000  7389.000000
#
#        num_followers  num_follows
# count   5.560000e+02   576.000000
# mean    8.835909e+04   508.381944
# std     9.262573e+05   917.981239
# min     0.000000e+00     0.000000
# 25%     3.800000e+01    57.500000
# 50%     1.415000e+02   229.500000
# 75%     7.285000e+02   589.500000
# max     1.533854e+07  7500.000000

# %%
data["description_length"]

# jetzt habe ich nur noch diese Spalte. Hier könnte ich es noch erweitern, bsp. data["description_length"].index
# Out:
# 0      53
# 1      44
# 2       0
# 3      82
# 4       0
#        ..
# 571     0
# 572    21
# 573     0
# 574    11
# 575     0
# Name: description_length, Length: 576, dtype: int64

# %%
data["description_length"].describe()
# Out:
# count    576.000000
# mean      22.623264
# std       37.702987
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       34.000000
# max      150.000000
# Name: description_length, dtype: float64

# %%
data["description_length"].std()
# Out:
# np.float64(37.70298680969428)

# %%
data["description_length"].median()
# Out:
# np.float64(0.0)

# %%
data.describe().info()

# man kann mehere Pandas Transformationen hintereinanderschalten
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   rel_num_numeric_char_username  8 non-null      float64
#  1   words_fullname                 8 non-null      float64
#  2   rel_num_numeric_char_fullname  8 non-null      float64
#  3   description_length             8 non-null      float64
#  4   num_posts                      8 non-null      float64
#  5   num_followers                  8 non-null      float64
#  6   num_follows                    8 non-null      float64
# dtypes: float64(7)
# memory usage: 512.0+ bytes

# %%
data.select_dtypes(include="number").corr

# nur die numerischen Spalten werden angezeigt. das kann man auch mit exclude machen 
# corr = Korrelation
# Out:
# <bound method DataFrame.corr of      rel_num_numeric_char_username  words_fullname  \
# 0                             0.27               0
# 1                             0.00               2
# 2                             0.10               2
# 3                             0.00               1
# 4                             0.00               2
# ..                             ...             ...
# 571                           0.55               1
# 572                           0.38               1
# 573                           0.57               2
# 574                           0.57               1
# 575                           0.27               1
#
#      rel_num_numeric_char_fullname  description_length  num_posts  \
# 0                             0.00                  53         32
# 1                             0.00                  44        286
# 2                             0.00                   0         13
# 3                             0.00                  82        679
# 4                             0.00                   0          6
# ..                             ...                 ...        ...
# 571                           0.44                   0         33
# 572                           0.33                  21         44
# 573                           0.00                   0          4
# 574                           0.00                  11          0
# 575                           0.00                   0          2
#
#      num_followers  num_follows
# 0           1000.0          955
# 1           2740.0          533
# 2            159.0           98
# 3            414.0          651
# 4            151.0          126
# ..             ...          ...
# 571            NaN          596
# 572           66.0           75
# 573           96.0          339
# 574           57.0           73
# 575          150.0          487
#
# [576 rows x 7 columns]>

# %%
data["profile_pic"].mode()
# Out:
# 0    yes
# Name: profile_pic, dtype: object

# %%
data["profile_pic"].value_counts()

# Zählen alle ausbringen von den Merkmalen (hier gibt es nur yes und no)
# Out:
# profile_pic
# yes    404
# no     172
# Name: count, dtype: int64

# %% [markdown]
# ## Datenvisualisierung mit pandas

# %%
data.plot()
# Out:
# <Axes: >

# %%
data["description_length"].plot()
# Out:
# <Axes: >

# %%
data["description_length"].plot(kind="line")
# Out:
# <Axes: >

# %%
data["description_length"].plot(kind="hist")

# hier sehen wir die meisten haben eine Bio von unter 20 Charakteren, die wenigsten haben eine längere Bio bei deren Profil
# das kind=hist zeigt die Art des Diagramms, also was für ein Diagramm es sein soll
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["description_length"].plot(kind="box")
# Out:
# <Axes: >

# %%
data["description_length"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
data["description_length"].plot(kind="bar")
# Out:
# <Axes: >

# %%
data["profile_pic"].value_counts().plot(
    kind="bar",
    title="Profiles with Profile Pictures",
    xlabel="Has Profile Pictures",
    ylabel="Number of Profiles",
    color="pink"
)
# Out:
# <Axes: title={'center': 'Profiles with Profile Pictures'}, xlabel='Has Profile Pictures', ylabel='Number of Profiles'>

# %% [markdown]
# ## Sonstige praktische Plots

# %%
from seaborn import heatmap, clustermap, pairplot

# %%
heatmap(
    data.select_dtypes(include="number").corr()
)
# Out:
# <Axes: >

# %%
clustermap(
    data.select_dtypes(include="number").corr(),
)

# %%
pairplot(data)

# %%
pairplot(data, hue="is_fake")
# Out:
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /workspaces/data-science-SS25/.venv/lib/python3.12/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
